# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn
# %matplotlib inline
# %pylab inline
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split
import math
from scipy.stats.mstats import gmean
from scipy.stats import entropy
from statsmodels.stats.weightstats import DescrStatsW
from itertools import combinations
from tqdm import tqdm
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\SCIENTIST\Anaconda2\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['entropy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
def priznak(p,t,n):
    
    t = np.array(t)
    w = np.arange(n, dtype=float)
    A = np.arange(n, dtype=float)
    
    for i in range(0,n):
        w[i] = t[i]/np.sum(t)
        
    for i in range(0,n):
        A[i] = p[i]*w[i]/(np.sum(p*w))    
    
    mean = np.mean(t)
    weighted_mean = np.sum(p*t)
    geometric_mean = gmean(t)
    weighted_geometric_mean = (t**p).prod()
    entropy_priznak = entropy(w)
    weighted_entropy = entropy(A)
    range_priznak = np.max(t) - np.min(t)
    weighted_range = p[t.argmax()]*np.max(t) - p[t.argmin()]*np.min(t)
    standard_deviation = np.std(t)
    
    weighted_stats = DescrStatsW(t, weights=p, ddof=0)
    weighted_standard_deviation = weighted_stats.std
    
    prznk = np.arange(10, dtype=float)
    prznk[0] = mean
    prznk[1] = weighted_mean
    prznk[2] = geometric_mean
    prznk[3] = weighted_geometric_mean
    prznk[4] = entropy_priznak
    prznk[5] = weighted_entropy
    prznk[6] = range_priznak
    prznk[7] = weighted_range
    prznk[8] = standard_deviation
    prznk[9] = weighted_standard_deviation
        
    return(prznk)

# %%
sc_min = pd.read_csv('sc00_min.csv', header=0, sep=',')
sc_max = pd.read_csv('sc00_max.csv', header=0, sep=',')
sc_mean = pd.read_csv('sc00_mean.csv', header=0, sep=',')

# %%
def material(p,t1,t2,t3,t4,t5,t6,t7,t8,n):
    data = sc_min.query("number_of_elements in [1]")
    data = data.drop('critical_temp', 1)
    data = data.drop('material', 1)
    data = data.iloc[0,:]
    
    data.iloc[0] = n
    for i in range(1,11):
        data.iloc[i] = priznak(p,t1,n)[i-1]
    for i in range(11,21):
        data.iloc[i] = priznak(p,t2,n)[i-11]
    for i in range(21,31):
        data.iloc[i] = priznak(p,t3,n)[i-21]
    for i in range(31,41):
        data.iloc[i] = priznak(p,t4,n)[i-31]
    for i in range(41,51):
        data.iloc[i] = priznak(p,t5,n)[i-41]
    for i in range(51,61):
        data.iloc[i] = priznak(p,t6,n)[i-51]
    for i in range(61,71):
        data.iloc[i] = priznak(p,t7,n)[i-61]
    for i in range(71,81):
        data.iloc[i] = priznak(p,t8,n)[i-71]
    data = data.to_frame().T
    return(data)

# %%
df = sc_min
target_cols = [col for col in df if col.startswith('mean')]
target_cols
# Out:
# ['mean_atomic_mass',
#  'mean_fie',
#  'mean_atomic_radius',
#  'mean_Density',
#  'mean_ElectronAffinity',
#  'mean_FusionHeat',
#  'mean_ThermalConductivity',
#  'mean_Valence']

# %%
def material1(p,t1,t2,t3,t4,t5,t6,t7,t8,n,name):
    data = sc_min.query("number_of_elements in [1]")
    data = data.drop('critical_temp', 1)
    #data = data.drop('material', 1)
    data = data.iloc[0,:]
    
    
    data.iloc[0] = n
    for i in range(1,11):
        data.iloc[i] = priznak(p,t1,n)[i-1]
    for i in range(11,21):
        data.iloc[i] = priznak(p,t2,n)[i-11]
    for i in range(21,31):
        data.iloc[i] = priznak(p,t3,n)[i-21]
    for i in range(31,41):
        data.iloc[i] = priznak(p,t4,n)[i-31]
    for i in range(41,51):
        data.iloc[i] = priznak(p,t5,n)[i-41]
    for i in range(51,61):
        data.iloc[i] = priznak(p,t6,n)[i-51]
    for i in range(61,71):
        data.iloc[i] = priznak(p,t7,n)[i-61]
    for i in range(71,81):
        data.iloc[i] = priznak(p,t8,n)[i-71]
    data.iloc[81] = name
    
    data = data.to_frame().T
    return(data)

# %%
sc11 = pd.DataFrame(columns=sc_min.columns)
sc11 = sc11.drop('critical_temp', 1)

sc11 = sc11.append(material1(np.ones(1),[1.00811],[1311.3],[53.],[0.0898],[72.7692],[0.558],[0.1805],[1.],1,'H1+-'))
sc11
# Out:
#      number_of_elements mean_atomic_mass wtd_mean_atomic_mass  \
# 7239                  1          1.00811              1.00811
#
#      gmean_atomic_mass wtd_gmean_atomic_mass entropy_atomic_mass  \
# 7239           1.00811               1.00811                   0
#
#      wtd_entropy_atomic_mass range_atomic_mass wtd_range_atomic_mass  \
# 7239                       0                 0                     0
#
#      std_atomic_mass   ...    wtd_mean_Valence gmean_Valence  \
# 7239               0   ...                   1             1
#
#      wtd_gmean_Valence entropy_Valence wtd_entropy_Valence range_Valence  \
# 7239                 1               0                   0             0
#
#      wtd_range_Valence std_Valence wtd_std_Valence material
# 7239                 0           0               0     H1+-
#
# [1 rows x 82 columns]

# %%
sc11 = pd.DataFrame(columns=sc_min.columns)
sc11 = sc11.drop('critical_temp', 1)

sc11 = sc11.append(material1(np.ones(1),[1.00811],[1311.3],[53.],[0.0898],[72.7692],[0.558],[0.1805],[1.],1,'H1+-'))
sc11 = sc11.append(material1(np.ones(1),[6.94],[520.2],[167.],[535.],[59.6],[3.],[85.],[1.],1,'Li1+'))
sc11 = sc11.append(material1(np.ones(1),[9.0121831],[899.5],[112.],[1848.],[-48.],[7.95],[190.],[2.],1,'Be2+'))
sc11 = sc11.append(material1(np.ones(1),[9.0121831],[899.5],[112.],[1848.],[-48.],[7.95],[190.],[1.],1,'Be1+'))
sc11 = sc11.append(material1(np.ones(1),[10.81],[800.6],[87.],[2460],[26.9],[50.],[27.],[3.],1,'B3+-'))
sc11 = sc11.append(material1(np.ones(1),[10.81],[800.6],[87.],[2460],[26.9],[50.],[27.],[2.],1,'B2+'))
sc11 = sc11.append(material1(np.ones(1),[10.81],[800.6],[87.],[2460],[26.9],[50.],[27.],[1.],1,'B1+-'))
sc11 = sc11.append(material1(np.ones(1),[12.011],[1086.5],[67.],[2260],[121.77],[105.],[140.],[4.],1,'C4+-'))
sc11 = sc11.append(material1(np.ones(1),[12.011],[1086.5],[67.],[2260],[121.77],[105.],[140.],[3.],1,'C3+-'))
sc11 = sc11.append(material1(np.ones(1),[12.011],[1086.5],[67.],[2260],[121.77],[105.],[140.],[2.],1,'C2+-'))
sc11 = sc11.append(material1(np.ones(1),[12.011],[1086.5],[67.],[2260],[121.77],[105.],[140.],[1.],1,'C1+-'))
sc11 = sc11.append(material1(np.ones(1),[14.007],[1402.3],[56.],[1.1649],[7.],[0.36],[0.02583],[5.],1,'N5+'))
sc11 = sc11.append(material1(np.ones(1),[14.007],[1402.3],[56.],[1.1649],[7.],[0.36],[0.02583],[4.],1,'N4+'))
sc11 = sc11.append(material1(np.ones(1),[14.007],[1402.3],[56.],[1.1649],[7.],[0.36],[0.02583],[3.],1,'N3+-'))
sc11 = sc11.append(material1(np.ones(1),[14.007],[1402.3],[56.],[1.1649],[7.],[0.36],[0.02583],[2.],1,'N2+-'))
sc11 = sc11.append(material1(np.ones(1),[14.007],[1402.3],[56.],[1.1649],[7.],[0.36],[0.02583],[1.],1,'N1+-'))
sc11 = sc11.append(material1(np.ones(1),[15.999],[1313.9],[48.],[1.42897],[141.],[0.222],[0.02658],[2.],1,'O2+-'))
sc11 = sc11.append(material1(np.ones(1),[15.999],[1313.9],[48.],[1.42897],[141.],[0.222],[0.02658],[1.],1,'O1+-'))
sc11 = sc11.append(material1(np.ones(1),[15.999],[1313.9],[48.],[1.42897],[141.],[0.222],[0.02658],[0.5],1,'O0.5+-'))
sc11 = sc11.append(material1(np.ones(1),[15.999],[1313.9],[48.],[1.42897],[141.],[0.222],[0.02658],[0.333],1,'O0.333+-'))
sc11 = sc11.append(material1(np.ones(1),[18.998],[1681.],[42.],[1.696],[328.],[0.26],[0.0277],[1.],1,'F1-'))
sc11 = sc11.append(material1(np.ones(1),[22.989],[495.8],[190.],[968.],[52.8],[2.6],[140.],[1.],1,'Na1+'))
sc11 = sc11.append(material1(np.ones(1),[24.305],[737.7],[145.],[1738.],[-40.],[8.7],[160.],[2.],1,'Mg2+'))
sc11 = sc11.append(material1(np.ones(1),[24.305],[737.7],[145.],[1738.],[-40.],[8.7],[160.],[1.],1,'Mg1+'))
sc11 = sc11.append(material1(np.ones(1),[26.981],[577.5],[118.],[2700.],[41.76],[10.7],[235.],[3.],1,'Al3+'))
sc11 = sc11.append(material1(np.ones(1),[28.085],[786.5],[111.],[2330.],[134.068],[50.2],[150.],[4.],1,'Si4+-'))
sc11 = sc11.append(material1(np.ones(1),[28.085],[786.5],[111.],[2330.],[134.068],[50.2],[150.],[3.],1,'Si3+-'))
sc11 = sc11.append(material1(np.ones(1),[28.085],[786.5],[111.],[2330.],[134.068],[50.2],[150.],[2.],1,'Si2+-'))
sc11 = sc11.append(material1(np.ones(1),[28.085],[786.5],[111.],[2330.],[134.068],[50.2],[150.],[1.],1,'Si1+-'))
sc11 = sc11.append(material1(np.ones(1),[30.973],[1011.8],[98.],[1823.],[72.],[0.64],[0.236],[5.],1,'P5+'))
sc11 = sc11.append(material1(np.ones(1),[30.973],[1011.8],[98.],[1823.],[72.],[0.64],[0.236],[4.],1,'P4+'))
sc11 = sc11.append(material1(np.ones(1),[30.973],[1011.8],[98.],[1823.],[72.],[0.64],[0.236],[3.],1,'P3+-'))
sc11 = sc11.append(material1(np.ones(1),[30.973],[1011.8],[98.],[1823.],[72.],[0.64],[0.236],[2.],1,'P2+-'))
sc11 = sc11.append(material1(np.ones(1),[30.973],[1011.8],[98.],[1823.],[72.],[0.64],[0.236],[1.],1,'P1+-'))
sc11 = sc11.append(material1(np.ones(1),[32.06],[999.6],[87.],[1960.],[200.],[1.73],[0.205],[6.],1,'S6+'))
sc11 = sc11.append(material1(np.ones(1),[32.06],[999.6],[87.],[1960.],[200.],[1.73],[0.205],[5.],1,'S5+'))
sc11 = sc11.append(material1(np.ones(1),[32.06],[999.6],[87.],[1960.],[200.],[1.73],[0.205],[4.],1,'S4+'))
sc11 = sc11.append(material1(np.ones(1),[32.06],[999.6],[87.],[1960.],[200.],[1.73],[0.205],[3.],1,'S3+'))
sc11 = sc11.append(material1(np.ones(1),[32.06],[999.6],[87.],[1960.],[200.],[1.73],[0.205],[2.],1,'S2+-'))
sc11 = sc11.append(material1(np.ones(1),[32.06],[999.6],[87.],[1960.],[200.],[1.73],[0.205],[1.],1,'S1+-'))
sc11 = sc11.append(material1(np.ones(1),[35.45],[1251.2],[79.],[3.214],[349.],[3.2],[0.0089],[7.],1,'Cl7+'))
sc11 = sc11.append(material1(np.ones(1),[35.45],[1251.2],[79.],[3.214],[349.],[3.2],[0.0089],[6.],1,'Cl6+'))
sc11 = sc11.append(material1(np.ones(1),[35.45],[1251.2],[79.],[3.214],[349.],[3.2],[0.0089],[5.],1,'Cl5+'))
sc11 = sc11.append(material1(np.ones(1),[35.45],[1251.2],[79.],[3.214],[349.],[3.2],[0.0089],[4.],1,'Cl4+'))
sc11 = sc11.append(material1(np.ones(1),[35.45],[1251.2],[79.],[3.214],[349.],[3.2],[0.0089],[3.],1,'Cl3+'))
sc11 = sc11.append(material1(np.ones(1),[35.45],[1251.2],[79.],[3.214],[349.],[3.2],[0.0089],[2.],1,'Cl2+'))
sc11 = sc11.append(material1(np.ones(1),[35.45],[1251.2],[79.],[3.214],[349.],[3.2],[0.0089],[1.],1,'Cl1+-'))
sc11 = sc11.append(material1(np.ones(1),[39.098],[418.8],[243.],[856.],[48.4],[2.33],[100.],[1.],1,'K1+'))
sc11 = sc11.append(material1(np.ones(1),[40.078],[589.8],[194.],[1550.],[2.37],[8.54],[200.],[2.],1,'Ca2+'))
sc11 = sc11.append(material1(np.ones(1),[44.955],[633.1],[184.],[2985.],[18.2],[16.],[16.],[3.],1,'Sc3+'))
sc11 = sc11.append(material1(np.ones(1),[44.955],[633.1],[184.],[2985.],[18.2],[16.],[16.],[2.],1,'Sc2+'))
sc11 = sc11.append(material1(np.ones(1),[44.955],[633.1],[184.],[2985.],[18.2],[16.],[16.],[1.],1,'Sc1+'))
sc11 = sc11.append(material1(np.ones(1),[47.867],[658.8],[176.],[4507.],[7.28],[18.7],[22.],[4.],1,'Ti4+'))
sc11 = sc11.append(material1(np.ones(1),[47.867],[658.8],[176.],[4507.],[7.28],[18.7],[22.],[3.],1,'Ti3+'))
sc11 = sc11.append(material1(np.ones(1),[47.867],[658.8],[176.],[4507.],[7.28],[18.7],[22.],[2.],1,'Ti2+'))
sc11 = sc11.append(material1(np.ones(1),[50.941],[650.9],[171.],[6110.],[50.9],[22.8],[31.],[5.],1,'V5+'))
sc11 = sc11.append(material1(np.ones(1),[50.941],[650.9],[171.],[6110.],[50.9],[22.8],[31.],[4.],1,'V4+'))
sc11 = sc11.append(material1(np.ones(1),[50.941],[650.9],[171.],[6110.],[50.9],[22.8],[31.],[3.],1,'V3+'))
sc11 = sc11.append(material1(np.ones(1),[50.941],[650.9],[171.],[6110.],[50.9],[22.8],[31.],[2.],1,'V2+'))
sc11 = sc11.append(material1(np.ones(1),[50.941],[650.9],[171.],[6110.],[50.9],[22.8],[31.],[1.],1,'V1+'))
sc11 = sc11.append(material1(np.ones(1),[51.996],[652.9],[166.],[7190.],[65.21],[20.5],[94.],[6.],1,'Cr6+'))
sc11 = sc11.append(material1(np.ones(1),[51.996],[652.9],[166.],[7190.],[65.21],[20.5],[94.],[5.],1,'Cr5+'))
sc11 = sc11.append(material1(np.ones(1),[51.996],[652.9],[166.],[7190.],[65.21],[20.5],[94.],[4.],1,'Cr4+'))
sc11 = sc11.append(material1(np.ones(1),[51.996],[652.9],[166.],[7190.],[65.21],[20.5],[94.],[3.],1,'Cr3+'))
sc11 = sc11.append(material1(np.ones(1),[51.996],[652.9],[166.],[7190.],[65.21],[20.5],[94.],[2.],1,'Cr2+'))
sc11 = sc11.append(material1(np.ones(1),[51.996],[652.9],[166.],[7190.],[65.21],[20.5],[94.],[1.],1,'Cr1+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[-50.],[13.2],[7.7],[7.],1,'Mn7+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[-50.],[13.2],[7.7],[6.],1,'Mn6+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[-50.],[13.2],[7.7],[5.],1,'Mn5+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[-50.],[13.2],[7.7],[4.],1,'Mn4+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[-50.],[13.2],[7.7],[3.],1,'Mn3+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[-50.],[13.2],[7.7],[2.],1,'Mn2+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[-50.],[13.2],[7.7],[1.],1,'Mn1+'))
sc11 = sc11.append(material1(np.ones(1),[55.845],[762.5],[156.],[7874.],[14.785],[13.8],[79.],[6.],1,'Fe6+'))
sc11 = sc11.append(material1(np.ones(1),[55.845],[762.5],[156.],[7874.],[14.785],[13.8],[79.],[5.],1,'Fe5+'))
sc11 = sc11.append(material1(np.ones(1),[55.845],[762.5],[156.],[7874.],[14.785],[13.8],[79.],[4.],1,'Fe4+'))
sc11 = sc11.append(material1(np.ones(1),[55.845],[762.5],[156.],[7874.],[14.785],[13.8],[79.],[3.],1,'Fe3+'))
sc11 = sc11.append(material1(np.ones(1),[55.845],[762.5],[156.],[7874.],[14.785],[13.8],[79.],[2.],1,'Fe2+'))
sc11 = sc11.append(material1(np.ones(1),[55.845],[762.5],[156.],[7874.],[14.785],[13.8],[79.],[1.],1,'Fe1+'))
sc11 = sc11.append(material1(np.ones(1),[58.933],[760.4],[152.],[8900.],[63.898],[16.2],[100.],[5.],1,'Co5+'))
sc11 = sc11.append(material1(np.ones(1),[58.933],[760.4],[152.],[8900.],[63.898],[16.2],[100.],[4.],1,'Co4+'))
sc11 = sc11.append(material1(np.ones(1),[58.933],[760.4],[152.],[8900.],[63.898],[16.2],[100.],[3.],1,'Co3+'))
sc11 = sc11.append(material1(np.ones(1),[58.933],[760.4],[152.],[8900.],[63.898],[16.2],[100.],[2.],1,'Co2+'))
sc11 = sc11.append(material1(np.ones(1),[58.933],[760.4],[152.],[8900.],[63.898],[16.2],[100.],[1.],1,'Co1+-'))
sc11 = sc11.append(material1(np.ones(1),[58.693],[737.1],[149.],[8908.],[111.65],[17.2],[91.],[4.],1,'Ni4+'))
sc11 = sc11.append(material1(np.ones(1),[58.693],[737.1],[149.],[8908.],[111.65],[17.2],[91.],[3.],1,'Ni3+'))
sc11 = sc11.append(material1(np.ones(1),[58.693],[737.1],[149.],[8908.],[111.65],[17.2],[91.],[2.],1,'Ni2+'))
sc11 = sc11.append(material1(np.ones(1),[58.693],[737.1],[149.],[8908.],[111.65],[17.2],[91.],[1.],1,'Ni1+'))
sc11 = sc11.append(material1(np.ones(1),[63.546],[745.5],[145.],[8960.],[119.2],[13.1],[400.],[2.],1,'Cu2+'))
sc11 = sc11.append(material1(np.ones(1),[63.546],[745.5],[145.],[8960.],[119.2],[13.1],[400.],[1.],1,'Cu1+'))
sc11 = sc11.append(material1(np.ones(1),[65.38],[906.4],[142.],[7140.],[-58.],[7.35],[120.],[2.],1,'Zn2+'))
sc11 = sc11.append(material1(np.ones(1),[69.723],[578.8],[136.],[5904.],[41.],[5.59],[29.],[3.],1,'Ga3+'))
sc11 = sc11.append(material1(np.ones(1),[69.723],[578.8],[136.],[5904.],[41.],[5.59],[29.],[2.],1,'Ga2+'))
sc11 = sc11.append(material1(np.ones(1),[69.723],[578.8],[136.],[5904.],[41.],[5.59],[29.],[1.],1,'Ga1+'))
sc11 = sc11.append(material1(np.ones(1),[72.63],[762.],[125.],[5323.],[119.],[31.8],[60.],[4.],1,'Ge4+-'))
sc11 = sc11.append(material1(np.ones(1),[72.63],[762.],[125.],[5323.],[119.],[31.8],[60.],[3.],1,'Ge3+'))
sc11 = sc11.append(material1(np.ones(1),[72.63],[762.],[125.],[5323.],[119.],[31.8],[60.],[2.],1,'Ge2+'))
sc11 = sc11.append(material1(np.ones(1),[72.63],[762.],[125.],[5323.],[119.],[31.8],[60.],[1.],1,'Ge1+'))
sc11 = sc11.append(material1(np.ones(1),[74.921],[947.],[114.],[5727.],[77.6],[27.7],[50.],[5.],1,'As5+'))
sc11 = sc11.append(material1(np.ones(1),[74.921],[947.],[114.],[5727.],[77.6],[27.7],[50.],[3.],1,'As3+-'))
sc11 = sc11.append(material1(np.ones(1),[74.921],[947.],[114.],[5727.],[77.6],[27.7],[50.],[2.],1,'As2+'))
sc11 = sc11.append(material1(np.ones(1),[78.971],[941.],[103.],[4819.],[195.],[5.4],[0.52],[6.],1,'Se6+'))
sc11 = sc11.append(material1(np.ones(1),[78.971],[941.],[103.],[4819.],[195.],[5.4],[0.52],[4.],1,'Se4+'))
sc11 = sc11.append(material1(np.ones(1),[78.971],[941.],[103.],[4819.],[195.],[5.4],[0.52],[2.],1,'Se2+-'))
sc11 = sc11.append(material1(np.ones(1),[79.904],[1139.9],[94.],[3120.],[324.6],[5.8],[0.12],[7.],1,'Br7+'))
sc11 = sc11.append(material1(np.ones(1),[79.904],[1139.9],[94.],[3120.],[324.6],[5.8],[0.12],[5.],1,'Br5+'))
sc11 = sc11.append(material1(np.ones(1),[79.904],[1139.9],[94.],[3120.],[324.6],[5.8],[0.12],[4.],1,'Br4+'))
sc11 = sc11.append(material1(np.ones(1),[79.904],[1139.9],[94.],[3120.],[324.6],[5.8],[0.12],[3.],1,'Br3+'))
sc11 = sc11.append(material1(np.ones(1),[79.904],[1139.9],[94.],[3120.],[324.6],[5.8],[0.12],[1.],1,'Br1+-'))
sc11 = sc11.append(material1(np.ones(1),[83.798],[1350.8],[87.],[3.75],[-96.],[1.64],[0.00943],[2.],1,'Kr2+'))
sc11 = sc11.append(material1(np.ones(1),[85.4678],[403.],[265.],[1532.],[46.9],[2.19],[58.],[1.],1,'Rb1+'))
sc11 = sc11.append(material1(np.ones(1),[87.62],[549.5],[219.],[2630.],[5.02],[8.],[35.],[2.],1,'Sr2+'))
sc11 = sc11.append(material1(np.ones(1),[88.905],[600.],[212.],[4472.],[29.6],[11.4],[17.],[3.],1,'Y3+'))
sc11 = sc11.append(material1(np.ones(1),[88.905],[600.],[212.],[4472.],[29.6],[11.4],[17.],[2.],1,'Y2+'))
sc11 = sc11.append(material1(np.ones(1),[88.905],[600.],[212.],[4472.],[29.6],[11.4],[17.],[1.],1,'Y1+'))
sc11 = sc11.append(material1(np.ones(1),[91.224],[640.1],[206.],[6511.],[41.8],[21.],[23.],[4.],1,'Zr4+'))
sc11 = sc11.append(material1(np.ones(1),[91.224],[640.1],[206.],[6511.],[41.8],[21.],[23.],[3.],1,'Zr3+'))
sc11 = sc11.append(material1(np.ones(1),[91.224],[640.1],[206.],[6511.],[41.8],[21.],[23.],[2.],1,'Zr2+'))
sc11 = sc11.append(material1(np.ones(1),[91.224],[640.1],[206.],[6511.],[41.8],[21.],[23.],[1.],1,'Zr1+'))
sc11 = sc11.append(material1(np.ones(1),[92.906],[652.1],[198.],[8570.],[88.516],[26.8],[54.],[5.],1,'Nb5+'))
sc11 = sc11.append(material1(np.ones(1),[92.906],[652.1],[198.],[8570.],[88.516],[26.8],[54.],[4.],1,'Nb4+'))
sc11 = sc11.append(material1(np.ones(1),[92.906],[652.1],[198.],[8570.],[88.516],[26.8],[54.],[3.],1,'Nb3+'))
sc11 = sc11.append(material1(np.ones(1),[92.906],[652.1],[198.],[8570.],[88.516],[26.8],[54.],[2.],1,'Nb2+'))
sc11 = sc11.append(material1(np.ones(1),[92.906],[652.1],[198.],[8570.],[88.516],[26.8],[54.],[1.],1,'Nb1-'))
sc11 = sc11.append(material1(np.ones(1),[95.95],[684.3],[190.],[10280.],[71.9],[36.],[139.],[6.],1,'Mo6+'))
sc11 = sc11.append(material1(np.ones(1),[95.95],[684.3],[190.],[10280.],[71.9],[36.],[139.],[5.],1,'Mo5+'))
sc11 = sc11.append(material1(np.ones(1),[95.95],[684.3],[190.],[10280.],[71.9],[36.],[139.],[4.],1,'Mo4+'))
sc11 = sc11.append(material1(np.ones(1),[95.95],[684.3],[190.],[10280.],[71.9],[36.],[139.],[3.],1,'Mo3+'))
sc11 = sc11.append(material1(np.ones(1),[95.95],[684.3],[190.],[10280.],[71.9],[36.],[139.],[2.],1,'Mo2+-'))
sc11 = sc11.append(material1(np.ones(1),[95.95],[684.3],[190.],[10280.],[71.9],[36.],[139.],[1.],1,'Mo1+-'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[7.],1,'Tc7+'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[6.],1,'Tc6+'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[5.],1,'Tc5+'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[4.],1,'Tc4+'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[3.],1,'Tc3+-'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[2.],1,'Tc2+'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[1.],1,'Tc1+-'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[8.],1,'Ru8+'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[7.],1,'Ru7+'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[6.],1,'Ru6+'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[5.],1,'Ru5+'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[4.],1,'Ru4+'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[3.],1,'Ru3+'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[2.],1,'Ru2+-'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[1.],1,'Ru1+'))
sc11 = sc11.append(material1(np.ones(1),[102.905],[719.7],[173.],[12450.],[110.27],[21.7],[150.],[6.],1,'Rh6+'))
sc11 = sc11.append(material1(np.ones(1),[102.905],[719.7],[173.],[12450.],[110.27],[21.7],[150.],[5.],1,'Rh5+'))
sc11 = sc11.append(material1(np.ones(1),[102.905],[719.7],[173.],[12450.],[110.27],[21.7],[150.],[4.],1,'Rh4+'))
sc11 = sc11.append(material1(np.ones(1),[102.905],[719.7],[173.],[12450.],[110.27],[21.7],[150.],[3.],1,'Rh3+'))
sc11 = sc11.append(material1(np.ones(1),[102.905],[719.7],[173.],[12450.],[110.27],[21.7],[150.],[2.],1,'Rh2+'))
sc11 = sc11.append(material1(np.ones(1),[102.905],[719.7],[173.],[12450.],[110.27],[21.7],[150.],[1.],1,'Rh1+-'))
sc11 = sc11.append(material1(np.ones(1),[106.42],[804.4],[169.],[12023.],[54.24],[16.7],[71.],[4.],1,'Pd4+'))
sc11 = sc11.append(material1(np.ones(1),[106.42],[804.4],[169.],[12023.],[54.24],[16.7],[71.],[2.],1,'Pd2+'))
sc11 = sc11.append(material1(np.ones(1),[107.868],[731.],[165.],[10490.],[125.6],[11.3],[430.],[3.],1,'Ag3+'))
sc11 = sc11.append(material1(np.ones(1),[107.868],[731.],[165.],[10490.],[125.6],[11.3],[430.],[2.],1,'Ag2+'))
sc11 = sc11.append(material1(np.ones(1),[107.868],[731.],[165.],[10490.],[125.6],[11.3],[430.],[1.],1,'Ag1+'))
sc11 = sc11.append(material1(np.ones(1),[112.414],[867.8],[161.],[8650],[-68.],[6.3],[96.],[2.],1,'Cd2+'))
sc11 = sc11.append(material1(np.ones(1),[114.818],[558.3],[156.],[7310.],[37.043],[3.26],[82.],[3.],1,'In3+'))
sc11 = sc11.append(material1(np.ones(1),[114.818],[558.3],[156.],[7310.],[37.043],[3.26],[82.],[2.],1,'In2+'))
sc11 = sc11.append(material1(np.ones(1),[114.818],[558.3],[156.],[7310.],[37.043],[3.26],[82.],[1.],1,'In1+'))
sc11 = sc11.append(material1(np.ones(1),[118.71],[708.6],[145.],[7310.],[107.3],[7.],[67.],[4.],1,'Sn4+-'))
sc11 = sc11.append(material1(np.ones(1),[118.71],[708.6],[145.],[7310.],[107.3],[7.],[67.],[2.],1,'Sn2+'))
sc11 = sc11.append(material1(np.ones(1),[121.76],[834.],[133.],[6697.],[103.2],[19.7],[24.],[5.],1,'Sb5+'))
sc11 = sc11.append(material1(np.ones(1),[121.76],[834.],[133.],[6697.],[103.2],[19.7],[24.],[3.],1,'Sb3+-'))
sc11 = sc11.append(material1(np.ones(1),[127.6],[869.3],[123.],[6240.],[190.2],[17.5],[3.],[6.],1,'Te6+'))
sc11 = sc11.append(material1(np.ones(1),[127.6],[869.3],[123.],[6240.],[190.2],[17.5],[3.],[5.],1,'Te5+'))
sc11 = sc11.append(material1(np.ones(1),[127.6],[869.3],[123.],[6240.],[190.2],[17.5],[3.],[4.],1,'Te4+'))
sc11 = sc11.append(material1(np.ones(1),[127.6],[869.3],[123.],[6240.],[190.2],[17.5],[3.],[2.],1,'Te2+-'))
sc11 = sc11.append(material1(np.ones(1),[126.904],[1008.4],[115.],[4940.],[295.2],[7.76],[0.449],[7.],1,'I7+'))
sc11 = sc11.append(material1(np.ones(1),[126.904],[1008.4],[115.],[4940.],[295.2],[7.76],[0.449],[5.],1,'I5+'))
sc11 = sc11.append(material1(np.ones(1),[126.904],[1008.4],[115.],[4940.],[295.2],[7.76],[0.449],[3.],1,'I3+'))
sc11 = sc11.append(material1(np.ones(1),[126.904],[1008.4],[115.],[4940.],[295.2],[7.76],[0.449],[1.],1,'I1+-'))
sc11 = sc11.append(material1(np.ones(1),[131.293],[1170.4],[108.],[5.9],[-77.],[2.3],[0.00565],[8.],1,'Xe8+'))
sc11 = sc11.append(material1(np.ones(1),[131.293],[1170.4],[108.],[5.9],[-77.],[2.3],[0.00565],[6.],1,'Xe6+'))
sc11 = sc11.append(material1(np.ones(1),[131.293],[1170.4],[108.],[5.9],[-77.],[2.3],[0.00565],[4.],1,'Xe4+'))
sc11 = sc11.append(material1(np.ones(1),[131.293],[1170.4],[108.],[5.9],[-77.],[2.3],[0.00565],[2.],1,'Xe2+'))
sc11 = sc11.append(material1(np.ones(1),[132.905],[375.7],[298.],[1879.],[45.5],[2.09],[36.],[1.],1,'Cs1+'))
sc11 = sc11.append(material1(np.ones(1),[137.327],[502.9],[253.],[3510.],[13.95],[8.],[18.],[2.],1,'Ba2+'))
sc11 = sc11.append(material1(np.ones(1),[138.905],[538.1],[187.],[6146.],[53.],[6.3],[13.],[3.],1,'La3+'))
sc11 = sc11.append(material1(np.ones(1),[138.905],[538.1],[187.],[6146.],[53.],[6.3],[13.],[2.],1,'La2+'))
sc11 = sc11.append(material1(np.ones(1),[140.116],[534.4],[181.],[6689.],[55.],[5.5],[11.],[4.],1,'Ce4+'))
sc11 = sc11.append(material1(np.ones(1),[140.116],[534.4],[181.],[6689.],[55.],[5.5],[11.],[3.],1,'Ce3+'))
sc11 = sc11.append(material1(np.ones(1),[140.116],[534.4],[181.],[6689.],[55.],[5.5],[11.],[2.],1,'Ce2+'))
sc11 = sc11.append(material1(np.ones(1),[140.907],[527.],[247.],[6640.],[93.],[6.9],[13.],[4.],1,'Pr4+'))
sc11 = sc11.append(material1(np.ones(1),[140.907],[527.],[247.],[6640.],[93.],[6.9],[13.],[3.],1,'Pr3+'))
sc11 = sc11.append(material1(np.ones(1),[140.907],[527.],[247.],[6640.],[93.],[6.9],[13.],[2.],1,'Pr2+'))
sc11 = sc11.append(material1(np.ones(1),[144.242],[533.1],[206.],[7010.],[184.87],[7.1],[17.],[3.],1,'Nd3+'))
sc11 = sc11.append(material1(np.ones(1),[144.242],[533.1],[206.],[7010.],[184.87],[7.1],[17.],[2.],1,'Nd2+'))
sc11 = sc11.append(material1(np.ones(1),[145.],[540.],[205.],[7264.],[12.45],[7.7],[15.],[3.],1,'Pm3+'))
sc11 = sc11.append(material1(np.ones(1),[150.36],[544.5],[238.],[7353.],[15.63],[8.5],[13.],[3.],1,'Sm3+'))
sc11 = sc11.append(material1(np.ones(1),[150.36],[544.5],[238.],[7353.],[15.63],[8.5],[13.],[2.],1,'Sm2+'))
sc11 = sc11.append(material1(np.ones(1),[151.964],[547.1],[231.],[5244.],[11.2],[9.3],[14.],[3.],1,'Eu3+'))
sc11 = sc11.append(material1(np.ones(1),[151.964],[547.1],[231.],[5244.],[11.2],[9.3],[14.],[2.],1,'Eu2+'))
sc11 = sc11.append(material1(np.ones(1),[157.25],[593.4],[233.],[7901.],[13.22],[10.],[11.],[3.],1,'Gd3+'))
sc11 = sc11.append(material1(np.ones(1),[157.25],[593.4],[233.],[7901.],[13.22],[10.],[11.],[2.],1,'Gd2+'))
sc11 = sc11.append(material1(np.ones(1),[157.25],[593.4],[233.],[7901.],[13.22],[10.],[11.],[1.],1,'Gd1+'))
sc11 = sc11.append(material1(np.ones(1),[158.925],[565.8],[225.],[8219.],[112.4],[10.8],[11.],[4.],1,'Tb4+'))
sc11 = sc11.append(material1(np.ones(1),[158.925],[565.8],[225.],[8219.],[112.4],[10.8],[11.],[3.],1,'Tb3+'))
sc11 = sc11.append(material1(np.ones(1),[158.925],[565.8],[225.],[8219.],[112.4],[10.8],[11.],[1.],1,'Tb1+'))
sc11 = sc11.append(material1(np.ones(1),[162.5],[573.],[228.],[8551.],[33.96],[11.1],[11.],[3.],1,'Dy3+'))
sc11 = sc11.append(material1(np.ones(1),[162.5],[573.],[228.],[8551.],[33.96],[11.1],[11.],[2.],1,'Dy2+'))
sc11 = sc11.append(material1(np.ones(1),[164.93],[581.],[226.],[8795.],[32.61],[17.],[16.],[3.],1,'Ho3+'))
sc11 = sc11.append(material1(np.ones(1),[167.259],[589.3],[226.],[9066.],[30.10],[19.9],[15.],[3.],1,'Er3+'))
sc11 = sc11.append(material1(np.ones(1),[168.934],[596.7],[222.],[9320.],[99.],[16.8],[17.],[3.],1,'Tm3+'))
sc11 = sc11.append(material1(np.ones(1),[168.934],[596.7],[222.],[9320.],[99.],[16.8],[17.],[2.],1,'Tm2+'))
sc11 = sc11.append(material1(np.ones(1),[173.045],[603.4],[222.],[6570.],[-1.93],[7.7],[39.],[3.],1,'Yb3+'))
sc11 = sc11.append(material1(np.ones(1),[173.045],[603.4],[222.],[6570.],[-1.93],[7.7],[39.],[2.],1,'Yb2+'))
sc11 = sc11.append(material1(np.ones(1),[174.966],[523.5],[217.],[9841.],[23.04],[22.],[16.],[3.],1,'Lu3+'))
sc11 = sc11.append(material1(np.ones(1),[178.49],[658.5],[208.],[13310.],[17.18],[25.5],[23.],[4.],1,'Hf4+'))
sc11 = sc11.append(material1(np.ones(1),[178.49],[658.5],[208.],[13310.],[17.18],[25.5],[23.],[3.],1,'Hf3+'))
sc11 = sc11.append(material1(np.ones(1),[178.49],[658.5],[208.],[13310.],[17.18],[25.5],[23.],[2.],1,'Hf2+'))
sc11 = sc11.append(material1(np.ones(1),[180.947],[761.],[200.],[16650.],[31.],[36.],[57.],[5.],1,'Ta5+'))
sc11 = sc11.append(material1(np.ones(1),[180.947],[761.],[200.],[16650.],[31.],[36.],[57.],[4.],1,'Ta4+'))
sc11 = sc11.append(material1(np.ones(1),[180.947],[761.],[200.],[16650.],[31.],[36.],[57.],[3.],1,'Ta3+'))
sc11 = sc11.append(material1(np.ones(1),[180.947],[761.],[200.],[16650.],[31.],[36.],[57.],[2.],1,'Ta2+'))
sc11 = sc11.append(material1(np.ones(1),[183.84],[770.],[193.],[19250.],[78.76],[35.],[170.],[6.],1,'W6+'))
sc11 = sc11.append(material1(np.ones(1),[183.84],[770.],[193.],[19250.],[78.76],[35.],[170.],[5.],1,'W5+'))
sc11 = sc11.append(material1(np.ones(1),[183.84],[770.],[193.],[19250.],[78.76],[35.],[170.],[4.],1,'W4+'))
sc11 = sc11.append(material1(np.ones(1),[183.84],[770.],[193.],[19250.],[78.76],[35.],[170.],[3.],1,'W3+'))
sc11 = sc11.append(material1(np.ones(1),[183.84],[770.],[193.],[19250.],[78.76],[35.],[170.],[2.],1,'W2+-'))
sc11 = sc11.append(material1(np.ones(1),[183.84],[770.],[193.],[19250.],[78.76],[35.],[170.],[1.],1,'W1+-'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[7.],1,'Re7+'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[6.],1,'Re6+'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[5.],1,'Re5+'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[4.],1,'Re4+'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[3.],1,'Re3+-'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[2.],1,'Re2+'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[1.],1,'Re1+-'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[8.],1,'Os8+'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[7.],1,'Os7+'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[6.],1,'Os6+'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[5.],1,'Os5+'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[4.],1,'Os4+'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[3.],1,'Os3+'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[2.],1,'Os2+-'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[1.],1,'Os1+-'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[9.],1,'Ir9+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[8.],1,'Ir8+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[7.],1,'Ir7+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[6.],1,'Ir6+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[5.],1,'Ir5+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[4.],1,'Ir4+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[3.],1,'Ir3+-'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[2.],1,'Ir2+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[1.],1,'Ir1+-'))
sc11 = sc11.append(material1(np.ones(1),[195.084],[870.],[177.],[21450.],[205.041],[20.],[71.],[6.],1,'Pt6+'))
sc11 = sc11.append(material1(np.ones(1),[195.084],[870.],[177.],[21450.],[205.041],[20.],[71.],[5.],1,'Pt5+'))
sc11 = sc11.append(material1(np.ones(1),[195.084],[870.],[177.],[21450.],[205.041],[20.],[71.],[4.],1,'Pt4+'))
sc11 = sc11.append(material1(np.ones(1),[195.084],[870.],[177.],[21450.],[205.041],[20.],[71.],[2.],1,'Pt2+'))
sc11 = sc11.append(material1(np.ones(1),[196.966],[890.1],[174.],[19300.],[222.747],[12.5],[320.],[5.],1,'Au5+'))
sc11 = sc11.append(material1(np.ones(1),[196.966],[890.1],[174.],[19300.],[222.747],[12.5],[320.],[3.],1,'Au3+'))
sc11 = sc11.append(material1(np.ones(1),[196.966],[890.1],[174.],[19300.],[222.747],[12.5],[320.],[2.],1,'Au2+'))
sc11 = sc11.append(material1(np.ones(1),[196.966],[890.1],[174.],[19300.],[222.747],[12.5],[320.],[1.],1,'Au1+-'))
sc11 = sc11.append(material1(np.ones(1),[200.592],[1007.1],[171.],[13534.],[-48.],[2.29],[8.3],[4.],1,'Hg4+'))
sc11 = sc11.append(material1(np.ones(1),[200.592],[1007.1],[171.],[13534.],[-48.],[2.29],[8.3],[2.],1,'Hg2+'))
sc11 = sc11.append(material1(np.ones(1),[200.592],[1007.1],[171.],[13534.],[-48.],[2.29],[8.3],[1.],1,'Hg1+'))
sc11 = sc11.append(material1(np.ones(1),[204.38],[589.4],[156.],[11850.],[36.4],[4.2],[46.],[3.],1,'Tl3+'))
sc11 = sc11.append(material1(np.ones(1),[204.38],[589.4],[156.],[11850.],[36.4],[4.2],[46.],[1.],1,'Tl1+'))
sc11 = sc11.append(material1(np.ones(1),[207.2],[715.6],[154.],[11340.],[34.418],[4.77],[35.],[4.],1,'Pb4+'))
sc11 = sc11.append(material1(np.ones(1),[207.2],[715.6],[154.],[11340.],[34.418],[4.77],[35.],[2.],1,'Pb2+'))
sc11 = sc11.append(material1(np.ones(1),[208.98],[703.],[143.],[9780.],[90.924],[10.9],[8.],[5.],1,'Bi5+'))
sc11 = sc11.append(material1(np.ones(1),[208.98],[703.],[143.],[9780.],[90.924],[10.9],[8.],[3.],1,'Bi3+-'))
sc11 = sc11.append(material1(np.ones(1),[209.],[812.1],[135.],[9196.],[136.],[13.],[20.],[6.],1,'Po6+'))
sc11 = sc11.append(material1(np.ones(1),[209.],[812.1],[135.],[9196.],[136.],[13.],[20.],[4.],1,'Po4+'))
sc11 = sc11.append(material1(np.ones(1),[209.],[812.1],[135.],[9196.],[136.],[13.],[20.],[2.],1,'Po2+-'))
sc11 = sc11.append(material1(np.ones(1),[210.],[899.0],[127.],[6350.],[233.],[6.],[1.7],[5.],1,'At5+'))
sc11 = sc11.append(material1(np.ones(1),[210.],[899.0],[127.],[6350.],[233.],[6.],[1.7],[3.],1,'At3+'))
sc11 = sc11.append(material1(np.ones(1),[210.],[899.0],[127.],[6350.],[233.],[6.],[1.7],[1.],1,'At1+-'))
sc11 = sc11.append(material1(np.ones(1),[222.],[1037.],[120.],[9.73],[-68.],[3.],[0.00361],[6.],1,'Rn6+'))
sc11 = sc11.append(material1(np.ones(1),[222.],[1037.],[120.],[9.73],[-68.],[3.],[0.00361],[4.],1,'Rn4+'))
sc11 = sc11.append(material1(np.ones(1),[222.],[1037.],[120.],[9.73],[-68.],[3.],[0.00361],[2.],1,'Rn2+'))
sc11 = sc11.append(material1(np.ones(1),[223.],[380.],[270.],[2900.],[46.89],[13.],[15.],[1.],1,'Fr1+'))
sc11 = sc11.append(material1(np.ones(1),[226.],[509.3],[215.],[5000.],[9.6485],[8.],[19.],[2.],1,'Ra2+'))
sc11 = sc11.append(material1(np.ones(1),[227.],[499.],[188.],[10070.],[33.77],[14.],[12.],[3.],1,'Ac3+'))
sc11 = sc11.append(material1(np.ones(1),[232.07],[587.],[180.],[11724.],[112.72],[16.],[54.],[4.],1,'Th4+'))
sc11 = sc11.append(material1(np.ones(1),[232.07],[587.],[180.],[11724.],[112.72],[16.],[54.],[3.],1,'Th3+'))
sc11 = sc11.append(material1(np.ones(1),[232.07],[587.],[180.],[11724.],[112.72],[16.],[54.],[2.],1,'Th2+'))
sc11 = sc11.append(material1(np.ones(1),[231.035],[568.],[163.],[15370.],[53.03],[15.],[47.],[5.],1,'Pa5+'))
sc11 = sc11.append(material1(np.ones(1),[231.035],[568.],[163.],[15370.],[53.03],[15.],[47.],[4.],1,'Pa4+'))
sc11 = sc11.append(material1(np.ones(1),[231.035],[568.],[163.],[15370.],[53.03],[15.],[47.],[3.],1,'Pa3+'))
sc11 = sc11.append(material1(np.ones(1),[238.028],[597.6],[138.],[19050.],[50.94],[14.],[27.],[6.],1,'U6+'))
sc11 = sc11.append(material1(np.ones(1),[238.028],[597.6],[138.],[19050.],[50.94],[14.],[27.],[5.],1,'U5+'))
sc11 = sc11.append(material1(np.ones(1),[238.028],[597.6],[138.],[19050.],[50.94],[14.],[27.],[4.],1,'U4+'))
sc11 = sc11.append(material1(np.ones(1),[238.028],[597.6],[138.],[19050.],[50.94],[14.],[27.],[3.],1,'U3+'))
sc11 = sc11.append(material1(np.ones(1),[237.],[604.5],[131.],[20450.],[45.85],[10.],[6.],[7.],1,'Np7+'))
sc11 = sc11.append(material1(np.ones(1),[237.],[604.5],[131.],[20450.],[45.85],[10.],[6.],[6.],1,'Np6+'))
sc11 = sc11.append(material1(np.ones(1),[237.],[604.5],[131.],[20450.],[45.85],[10.],[6.],[5.],1,'Np5+'))
sc11 = sc11.append(material1(np.ones(1),[237.],[604.5],[131.],[20450.],[45.85],[10.],[6.],[4.],1,'Np4+'))
sc11 = sc11.append(material1(np.ones(1),[237.],[604.5],[131.],[20450.],[45.85],[10.],[6.],[3.],1,'Np3+'))
sc11 = sc11.append(material1(np.ones(1),[244.],[584.7],[151.],[19816.],[-48.33],[2.84],[7.],[3.],1,'Pu7+'))
sc11 = sc11.append(material1(np.ones(1),[244.],[584.7],[151.],[19816.],[-48.33],[2.84],[6.],[3.],1,'Pu6+'))
sc11 = sc11.append(material1(np.ones(1),[244.],[584.7],[151.],[19816.],[-48.33],[2.84],[5.],[3.],1,'Pu5+'))
sc11 = sc11.append(material1(np.ones(1),[244.],[584.7],[151.],[19816.],[-48.33],[2.84],[4.],[3.],1,'Pu4+'))
sc11 = sc11.append(material1(np.ones(1),[244.],[584.7],[151.],[19816.],[-48.33],[2.84],[3.],[3.],1,'Pu3+'))
sc11 = sc11.append(material1(np.ones(1),[243.],[578.],[184.],[13670.],[9.93],[14.40],[10.],[6.],1,'Am6+'))
sc11 = sc11.append(material1(np.ones(1),[243.],[578.],[184.],[13670.],[9.93],[14.40],[10.],[5.],1,'Am5+'))
sc11 = sc11.append(material1(np.ones(1),[243.],[578.],[184.],[13670.],[9.93],[14.40],[10.],[4.],1,'Am4+'))
sc11 = sc11.append(material1(np.ones(1),[243.],[578.],[184.],[13670.],[9.93],[14.40],[10.],[3.],1,'Am3+'))
sc11 = sc11.append(material1(np.ones(1),[243.],[578.],[184.],[13670.],[9.93],[14.40],[10.],[2.],1,'Am2+'))
sc11 = sc11.append(material1(np.ones(1),[247.],[581.],[174.],[13510.],[27.17],[15.],[10.],[4.],1,'Cm2+'))
sc11 = sc11.append(material1(np.ones(1),[247.],[581.],[174.],[13510.],[27.17],[15.],[10.],[3.],1,'Cm3+'))
sc11 = sc11.append(material1(np.ones(1),[247.],[601.],[170.],[14780.],[-165.24],[7.92],[10.],[4.],1,'Bk4+'))
sc11 = sc11.append(material1(np.ones(1),[247.],[601.],[170.],[14780.],[-165.24],[7.92],[10.],[3.],1,'Bk3+'))



sc11
# Out:
#      number_of_elements mean_atomic_mass wtd_mean_atomic_mass  \
# 7239                  1          1.00811              1.00811
# 7239                  1             6.94                 6.94
# 7239                  1          9.01218              9.01218
# 7239                  1          9.01218              9.01218
# 7239                  1            10.81                10.81
# 7239                  1            10.81                10.81
# 7239                  1            10.81                10.81
# 7239                  1           12.011               12.011
# 7239                  1           12.011               12.011
# 7239                  1           12.011               12.011
# 7239                  1           12.011               12.011
# 7239                  1           14.007               14.007
# 7239                  1           14.007               14.007
# 7239                  1           14.007               14.007
# ...

# %%
sc11.to_csv('table_one.csv', sep=',', header=True, index=False)

# %%
sc11 = pd.DataFrame(columns=sc_min.columns)
sc11 = sc11.drop('critical_temp', 1)
sc11 = sc11.append(material1(np.ones(1),[15.999],[1313.9],[48.],[1.42897],[141.],[0.222],[0.02658],[2.],1,'O2-'))
sc11.to_csv('test_minus.csv', sep=',', header=True, index=False)

# %%
one_plus = pd.read_csv('table_one_plus_zero.csv', header=0, sep=',')
one_minus = pd.read_csv('table_one_minus.csv', header=0, sep=',')
one_chast_plus = pd.read_csv('one_chast_plus.csv', header=0, sep=',')

# %%
n = 3
res_scores = []
for (_, row1), (_, row2) in tqdm(combinations(one_chast_plus.iterrows(), 2)):
    for _, row3 in one_minus.iterrows():
        
        p = np.ones(n)
        p[2] = (row1['mean_Valence']+3*row2['mean_Valence'])/(row1['mean_Valence']+3*row2['mean_Valence']+4*row3['mean_Valence']) 
        p[0] = (1 - p[2])/4.
        p[1] = 3*(1 - p[2])/4.
        #p[0] = row3['mean_Valence']/(row1['mean_Valence']+row2['mean_Valence']+row3['mean_Valence']+row3['mean_Valence'])
        #p[1] = row3['mean_Valence']/(row1['mean_Valence']+row2['mean_Valence']+row3['mean_Valence']+row3['mean_Valence'])
        #p[2] = (row1['mean_Valence']+row2['mean_Valence'])/(row1['mean_Valence']+row2['mean_Valence']+row3['mean_Valence']+row3['mean_Valence'])
        ts = []
        for target_col in target_cols:
            t = [row1[target_col], row2[target_col], row3[target_col]]
            ts.append(t)
    
        params = material(p,ts[0],ts[1],ts[2],ts[3],ts[4],ts[5],ts[6],ts[7],n)
        pred_temp = rfst.predict(params)
        res_scores.append({'material1':row1['material'], 'material2':row2['material'],'material3':row3['material'], 'weights':p,'pred_temp':pred_temp})
# Out:
# 1it [00:03,  3.25s/it]C:\Users\SCIENTIST\Anaconda2\lib\site-packages\scipy\stats\stats.py:313: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(a)
# 8646it [19:38:18,  4.19s/it]

# %%
res_scores_df = pd.DataFrame(res_scores)
res_scores_df.sort_values('pred_temp', ascending=False)
#res_scores_df.sort_values('pred_temp', ascending=False).to_csv('res_three_rfst_plus_134.csv', sep=',', header=True, index=False)
# Out:
#        material1 material2 material3              pred_temp  \
# 74687       Si4+      Cu2+       O2-    [95.45808123249302]
# 29054        C4+      Cu2+       O2-    [93.94467787114849]
# 158162      Cr6+      Cu2+       O2-    [85.69634453781514]
# 152544       V5+      Cu2+       O2-     [82.7715406162465]
# 42352        N5+      Cu2+       C2-    [82.50084000266774]
# 68327       Al3+      Cu2+       O2-    [78.96122612681437]
# 22323        B3+      Cu2+       O2-    [78.93776610644258]
# 213918      Cu2+      Ba2+       O2-    [78.22467156093207]
# 212275      Cu2+      Sr2+       O2-    [78.05228984927305]
# 174698      Mn4+      Cu2+       O2-    [77.08872549019605]
# 146873      Ti4+      Cu2+       O2-    [77.02259103641458]
# 87248        P3+      Cu2+       O2-    [76.49820728291317]
# 163727      Cr3+      Cu2+       O2-    [75.65612044817928]
# 48924        N3+      Cu2+       C2-     [74.8550252828404]
# 338390      Ag1+      Cs1+      Sb3-     [74.4914677204215]
# ...

# %%
# %%time
from itertools import product
import math
n = 2
res_scores = []
for (_, row1), (_, row2) in product(one_plus.iterrows(), one_minus.iterrows()):
    print(row1['material'], row2['material'])
    
    p = np.ones(n)
    
    p[0] = row2['mean_Valence']/(row1['mean_Valence']+row2['mean_Valence'])
    p[1] = row1['mean_Valence']/(row1['mean_Valence']+row2['mean_Valence'])
   
    ts = []
    for target_col in target_cols:
        t = [row1[target_col], row2[target_col]]
        ts.append(t)
    
    params_0 = material(p,ts[0],ts[1],ts[2],ts[3],ts[4],ts[5],ts[6],ts[7],n)
    #params_0 = params_0.drop('number_of_elements', 1)
    #pred_temp = lin.predict(params_0)
    pred_temp = rfst.predict(params_0)
    res_scores.append({'material1':row1['material'], 'material2':row2['material'], 'weights':p,'pred_temp':pred_temp})
# Out:
# ('H1+', 'H1-')
# ('H1+', 'B3-')
# ('H1+', 'B1-')
# ('H1+', 'C4-')
# ('H1+', 'C3-')
# ('H1+', 'C2-')
# ('H1+', 'C1-')
# ('H1+', 'N3-')
# ('H1+', 'N2-')
# ('H1+', 'N1-')
# ('H1+', 'O2-')
# ('H1+', 'O1-')
# ('H1+', 'O0.5-')
# ('H1+', 'O0.333-')
# ('H1+', 'F1-')
# ('H1+', 'Si4-')
# ('H1+', 'Si3-')
# ('H1+', 'Si2-')
# ('H1+', 'Si1-')
# ('H1+', 'P3-')
# ('H1+', 'P2-')
# ('H1+', 'P1-')
# ('H1+', 'S2-')
# ('H1+', 'S1-')
# ('H1+', 'Cl1-')
# ('H1+', 'Co1-')
# ('H1+', 'Ge4-')
# ('H1+', 'As3-')
# ('H1+', 'Se2-')
# ('H1+', 'Br1-')
# ('H1+', 'Nb1-')
# ('H1+', 'Mo2-')
# ('H1+', 'Mo1-')
# ('H1+', 'Tc3-')
# ('H1+', 'Tc1-')
# ('H1+', 'Ru2-')
# ('H1+', 'Rh1-')
# ('H1+', 'Sn4-')
# ('H1+', 'Sb3-')
# ('H1+', 'Te2-')
# ('H1+', 'I1-')
# ('H1+', 'W2-')
# ('H1+', 'W1-')
# ('H1+', 'Re3-')
# ('H1+', 'Re1-')
# ('H1+', 'Os2-')
# ('H1+', 'Os1-')
# ('H1+', 'Ir3-')
# ('H1+', 'Ir1-')
# ('H1+', 'Au1-')
# ('H1+', 'Bi3-')
# ('H1+', 'Po2-')
# ('H1+', 'At1-')
# ('Li1+', 'H1-')
# ('Li1+', 'B3-')
# ('Li1+', 'B1-')
# ...

# %%
res_scores_df = pd.DataFrame(res_scores)
#res_scores_df.sort_values('pred_temp', ascending=False).head(540)
res_scores_df.sort_values('pred_temp', ascending=False).to_csv('res_two_rfst_max.csv', sep=',', header=True, index=False)

# %%
#metals
sc11 = pd.DataFrame(columns=sc_min.columns)
sc11 = sc11.drop('critical_temp', 1)

sc11 = sc11.append(material1(np.ones(1),[6.94],[520.2],[167.],[535.],[59.6],[3.],[85.],[1.],1,'Li1+'))
sc11 = sc11.append(material1(np.ones(1),[9.0121831],[899.5],[112.],[1848.],[0.],[7.95],[190.],[2.],1,'Be2+'))
sc11 = sc11.append(material1(np.ones(1),[22.989],[495.8],[190.],[968.],[52.8],[2.6],[140.],[1.],1,'Na1+'))
sc11 = sc11.append(material1(np.ones(1),[24.305],[737.7],[145.],[1738.],[0.],[8.7],[160.],[2.],1,'Mg2+'))
sc11 = sc11.append(material1(np.ones(1),[26.981],[577.5],[118.],[2700.],[41.76],[10.7],[235.],[3.],1,'Al3+'))
sc11 = sc11.append(material1(np.ones(1),[39.098],[418.8],[243.],[856.],[48.4],[2.33],[100.],[1.],1,'K1+'))
sc11 = sc11.append(material1(np.ones(1),[40.078],[589.8],[194.],[1550.],[2.37],[8.54],[200.],[2.],1,'Ca2+'))
sc11 = sc11.append(material1(np.ones(1),[44.955],[633.1],[184.],[2985.],[18.2],[16.],[16.],[3.],1,'Sc3+'))
sc11 = sc11.append(material1(np.ones(1),[47.867],[658.8],[176.],[4507.],[7.28],[18.7],[22.],[4.],1,'Ti4+'))
sc11 = sc11.append(material1(np.ones(1),[50.941],[650.9],[171.],[6110.],[50.9],[22.8],[31.],[5.],1,'V5+'))
sc11 = sc11.append(material1(np.ones(1),[51.996],[652.9],[166.],[7190.],[65.21],[20.5],[94.],[3.],1,'Cr3+'))
sc11 = sc11.append(material1(np.ones(1),[54.938],[717.3],[161.],[7470.],[0.],[13.2],[7.7],[2.],1,'Mn2+'))
sc11 = sc11.append(material1(np.ones(1),[55.845],[762.5],[156.],[7874.],[14.785],[13.8],[79.],[3.],1,'Fe3+'))
sc11 = sc11.append(material1(np.ones(1),[58.933],[760.4],[152.],[8900.],[63.898],[16.2],[100.],[3.],1,'Co3+'))
sc11 = sc11.append(material1(np.ones(1),[58.693],[737.1],[149.],[8908.],[111.65],[17.2],[91.],[2.],1,'Ni2+'))
sc11 = sc11.append(material1(np.ones(1),[63.546],[745.5],[145.],[8960.],[119.2],[13.1],[400.],[2.],1,'Cu2+'))
sc11 = sc11.append(material1(np.ones(1),[65.38],[906.4],[142.],[7140.],[0.],[7.35],[120.],[2.],1,'Zn2+'))
sc11 = sc11.append(material1(np.ones(1),[69.723],[578.8],[136.],[5904.],[41.],[5.59],[29.],[3.],1,'Ga3+'))

sc11 = sc11.append(material1(np.ones(1),[85.4678],[403.],[265.],[1532.],[46.9],[2.19],[58.],[1.],1,'Rb1+'))
sc11 = sc11.append(material1(np.ones(1),[87.62],[549.5],[219.],[2630.],[5.02],[8.],[35.],[2.],1,'Sr2+'))
sc11 = sc11.append(material1(np.ones(1),[88.905],[600.],[212.],[4472.],[29.6],[11.4],[17.],[3.],1,'Y3+'))
sc11 = sc11.append(material1(np.ones(1),[91.224],[640.1],[206.],[6511.],[41.8],[21.],[23.],[4.],1,'Zr4+'))
sc11 = sc11.append(material1(np.ones(1),[92.906],[652.1],[198.],[8570.],[88.516],[26.8],[54.],[5.],1,'Nb5+'))
sc11 = sc11.append(material1(np.ones(1),[95.95],[684.3],[190.],[10280.],[71.9],[36.],[139.],[4.],1,'Mo4+'))
sc11 = sc11.append(material1(np.ones(1),[97.],[702.],[183.],[11500.],[53.],[23.],[51.],[4.],1,'Tc4+'))
sc11 = sc11.append(material1(np.ones(1),[101.07],[710.2],[178.],[12370.],[100.96],[25.7],[120.],[3.],1,'Ru3+'))
sc11 = sc11.append(material1(np.ones(1),[102.905],[719.7],[173.],[12450.],[110.27],[21.7],[150.],[3.],1,'Rh3+'))
sc11 = sc11.append(material1(np.ones(1),[106.42],[804.4],[169.],[12023.],[54.24],[16.7],[71.],[4.],1,'Pd4+'))
sc11 = sc11.append(material1(np.ones(1),[107.868],[731.],[165.],[10490.],[125.6],[11.3],[430.],[1.],1,'Ag1+'))
sc11 = sc11.append(material1(np.ones(1),[112.414],[867.8],[161.],[8650],[0.],[6.3],[96.],[2.],1,'Cd2+'))
sc11 = sc11.append(material1(np.ones(1),[114.818],[558.3],[156.],[7310.],[37.043],[3.26],[82.],[3.],1,'In3+'))
sc11 = sc11.append(material1(np.ones(1),[118.71],[708.6],[145.],[7310.],[107.3],[7.],[67.],[2.],1,'Sn2+'))
sc11 = sc11.append(material1(np.ones(1),[121.76],[834.],[133.],[6697.],[103.2],[19.7],[24.],[3.],1,'Sb3+'))
sc11 = sc11.append(material1(np.ones(1),[127.6],[869.3],[123.],[6240.],[190.2],[17.5],[3.],[2.],1,'Te2+'))

sc11 = sc11.append(material1(np.ones(1),[132.905],[375.7],[298.],[1879.],[45.5],[2.09],[36.],[1.],1,'Cs1+'))
sc11 = sc11.append(material1(np.ones(1),[137.327],[502.9],[253.],[3510.],[13.95],[8.],[18.],[2.],1,'Ba2+'))
sc11 = sc11.append(material1(np.ones(1),[138.905],[538.1],[187.],[6146.],[53.],[6.3],[13.],[3.],1,'La3+'))
sc11 = sc11.append(material1(np.ones(1),[140.116],[534.4],[181.],[6689.],[55.],[5.5],[11.],[3.],1,'Ce3+'))
sc11 = sc11.append(material1(np.ones(1),[140.907],[527.],[247.],[6640.],[93.],[6.9],[13.],[3.],1,'Pr3+'))
sc11 = sc11.append(material1(np.ones(1),[144.242],[533.1],[206.],[7010.],[184.87],[7.1],[17.],[3.],1,'Nd3+'))
sc11 = sc11.append(material1(np.ones(1),[145.],[540.],[205.],[7264.],[12.45],[7.7],[15.],[3.],1,'Pm3+'))
sc11 = sc11.append(material1(np.ones(1),[150.36],[544.5],[238.],[7353.],[15.63],[8.5],[13.],[3.],1,'Sm3+'))
sc11 = sc11.append(material1(np.ones(1),[151.964],[547.1],[231.],[5244.],[11.2],[9.3],[14.],[3.],1,'Eu3+'))
sc11 = sc11.append(material1(np.ones(1),[157.25],[593.4],[233.],[7901.],[13.22],[10.],[11.],[3.],1,'Gd3+'))
sc11 = sc11.append(material1(np.ones(1),[158.925],[565.8],[225.],[8219.],[112.4],[10.8],[11.],[3.],1,'Tb3+'))
sc11 = sc11.append(material1(np.ones(1),[162.5],[573.],[228.],[8551.],[33.96],[11.1],[11.],[3.],1,'Dy3+'))
sc11 = sc11.append(material1(np.ones(1),[164.93],[581.],[226.],[8795.],[32.61],[17.],[16.],[3.],1,'Ho3+'))
sc11 = sc11.append(material1(np.ones(1),[167.259],[589.3],[226.],[9066.],[30.10],[19.9],[15.],[3.],1,'Er3+'))
sc11 = sc11.append(material1(np.ones(1),[168.934],[596.7],[222.],[9320.],[99.],[16.8],[17.],[3.],1,'Tm3+'))
sc11 = sc11.append(material1(np.ones(1),[173.045],[603.4],[222.],[6570.],[0.],[7.7],[39.],[3.],1,'Yb3+'))
sc11 = sc11.append(material1(np.ones(1),[174.966],[523.5],[217.],[9841.],[23.04],[22.],[16.],[3.],1,'Lu3+'))
sc11 = sc11.append(material1(np.ones(1),[178.49],[658.5],[208.],[13310.],[17.18],[25.5],[23.],[4.],1,'Hf4+'))
sc11 = sc11.append(material1(np.ones(1),[180.947],[761.],[200.],[16650.],[31.],[36.],[57.],[5.],1,'Ta5+'))
sc11 = sc11.append(material1(np.ones(1),[183.84],[770.],[193.],[19250.],[78.76],[35.],[170.],[6.],1,'W6+'))
sc11 = sc11.append(material1(np.ones(1),[186.207],[760.],[188.],[21020.],[5.827],[33.],[48.],[4.],1,'Re4+'))
sc11 = sc11.append(material1(np.ones(1),[190.23],[840.],[185.],[22590.],[103.99],[31.],[87.],[4.],1,'Os4+'))
sc11 = sc11.append(material1(np.ones(1),[192.217],[880.],[180.],[22560.],[150.94],[26.],[150.],[3.],1,'Ir3+'))
sc11 = sc11.append(material1(np.ones(1),[195.084],[870.],[177.],[21450.],[205.041],[20.],[71.],[2.],1,'Pt2+'))
sc11 = sc11.append(material1(np.ones(1),[196.966],[890.1],[174.],[19300.],[222.747],[12.5],[320.],[3.],1,'Au3+'))
sc11 = sc11.append(material1(np.ones(1),[200.592],[1007.1],[171.],[13534.],[0.],[2.29],[8.3],[1.],1,'Hg1+'))
sc11 = sc11.append(material1(np.ones(1),[204.38],[589.4],[156.],[11850.],[36.4],[4.2],[46.],[1.],1,'Tl1+'))
sc11 = sc11.append(material1(np.ones(1),[207.2],[715.6],[154.],[11340.],[34.418],[4.77],[35.],[2.],1,'Pb2+'))
sc11 = sc11.append(material1(np.ones(1),[208.98],[703.],[143.],[9780.],[90.924],[10.9],[8.],[3.],1,'Bi3+'))
sc11 = sc11.append(material1(np.ones(1),[209.],[812.1],[135.],[9196.],[136.],[13.],[20.],[2.],1,'Po2+'))
sc11 = sc11.append(material1(np.ones(1),[223.],[380.],[270.],[2900.],[46.89],[13.],[15.],[1.],1,'Fr1+'))
sc11 = sc11.append(material1(np.ones(1),[226.],[509.3],[215.],[5000.],[9.6485],[8.],[19.],[2.],1,'Ra2+'))
sc11 = sc11.append(material1(np.ones(1),[227.],[499.],[188.],[10070.],[33.77],[14.],[12.],[3.],1,'Ac3+'))
sc11 = sc11.append(material1(np.ones(1),[232.07],[587.],[180.],[11724.],[112.72],[16.],[54.],[4.],1,'Th4+'))
sc11 = sc11.append(material1(np.ones(1),[231.035],[568.],[163.],[15370.],[53.03],[15.],[47.],[5.],1,'Pa5+'))
sc11 = sc11.append(material1(np.ones(1),[238.028],[597.6],[138.],[19050.],[50.94],[14.],[27.],[6.],1,'U6+'))
sc11 = sc11.append(material1(np.ones(1),[237.],[604.5],[131.],[20450.],[45.85],[10.],[6.],[5.],1,'Np5+'))
sc11 = sc11.append(material1(np.ones(1),[244.],[584.7],[151.],[19816.],[0.],[2.84],[4.],[3.],1,'Pu4+'))
sc11 = sc11.append(material1(np.ones(1),[243.],[578.],[184.],[13670.],[9.93],[14.40],[10.],[3.],1,'Am3+'))
sc11 = sc11.append(material1(np.ones(1),[247.],[581.],[174.],[13510.],[27.17],[15.],[10.],[3.],1,'Cm3+'))
sc11 = sc11.append(material1(np.ones(1),[247.],[601.],[170.],[14780.],[0.],[7.92],[10.],[3.],1,'Bk3+'))



sc11
# Out:
# C:\Users\SCIENTIST\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
#      number_of_elements mean_atomic_mass wtd_mean_atomic_mass  \
# 7239                  1             6.94                 6.94
# 7239                  1          9.01218              9.01218
# 7239                  1           22.989               22.989
# 7239                  1           24.305               24.305
# 7239                  1           26.981               26.981
# 7239                  1           39.098               39.098
# 7239                  1           40.078               40.078
# 7239                  1           44.955               44.955
# 7239                  1           47.867               47.867
# 7239                  1           50.941               50.941
# 7239                  1           51.996               51.996
# 7239                  1           54.938               54.938
# ...

# %%
sc11.to_csv('one_metals.csv', sep=',', header=True, index=False)

# %%
df = sc_min
drop_cols1 = [col for col in df if col.endswith('_Valence')]
drop_cols2 = [col for col in df if col.endswith('_ElectronAffinity')]
drop_cols2
# Out:
# ['mean_ElectronAffinity',
#  'wtd_mean_ElectronAffinity',
#  'gmean_ElectronAffinity',
#  'wtd_gmean_ElectronAffinity',
#  'entropy_ElectronAffinity',
#  'wtd_entropy_ElectronAffinity',
#  'range_ElectronAffinity',
#  'wtd_range_ElectronAffinity',
#  'std_ElectronAffinity',
#  'wtd_std_ElectronAffinity']

# %%
sc11 = sc_mean.query("number_of_elements in [2,3,4,5,6,7,8,9]")
X = sc11.drop('critical_temp', 1)
X = X.drop('material', 1)
X = X.drop(drop_cols1,1)
X = X.drop(drop_cols2,1)
X = X.drop('number_of_elements', 1)
y = sc11['critical_temp']
train_data, test_data, train_labels, test_labels = train_test_split(X, y, test_size = 0.3,random_state = 0)
rfst1 = RandomForestRegressor(max_depth=22, random_state=0, n_estimators=119, min_impurity_decrease=0.0007)
rfst1.fit(train_data, train_labels)
r20=metrics.r2_score(test_labels,rfst1.predict(test_data))
r21=metrics.mean_absolute_error(test_labels,rfst1.predict(test_data))
r22=metrics.mean_squared_error(test_labels,rfst1.predict(test_data))
print(r20,r21,r22)
# Out:
# (0.9124554801505709, 5.522827603436505, 97.55220773144863)

# %%
# %%time
from itertools import product
import math
n = 2
res_scores = []
for (_, row1), (_, row2) in combinations(metals.iterrows(), 2):
    print(row1['material'], row2['material'])
    
    p = np.ones(n)
    
    p[0]=6/7.
    p[1]=1/7.
    #p[0] = row2['mean_Valence']/(row1['mean_Valence']+row2['mean_Valence'])
    #p[1] = row1['mean_Valence']/(row1['mean_Valence']+row2['mean_Valence'])
   
    ts = []
    for target_col in target_cols:
        t = [row1[target_col], row2[target_col]]
        ts.append(t)
    
    params = material(p,ts[0],ts[1],ts[2],ts[3],ts[4],ts[5],ts[6],ts[7],n)
    params = params.drop(drop_cols1,1)
    params = params.drop(drop_cols2,1)
    params = params.drop('number_of_elements', 1)
    pred_temp = rfst1.predict(params)
    res_scores.append({'material1':row1['material'], 'material2':row2['material'], 'weights':p,'pred_temp':pred_temp})
# Out:
# ('Li1+', 'Be2+')
# ('Li1+', 'Na1+')
# ('Li1+', 'Mg2+')
# ('Li1+', 'Al3+')
# ('Li1+', 'K1+')
# ('Li1+', 'Ca2+')
# ('Li1+', 'Sc3+')
# ('Li1+', 'Ti4+')
# ('Li1+', 'V5+')
# ('Li1+', 'Cr3+')
# ('Li1+', 'Mn2+')
# ('Li1+', 'Fe3+')
# ('Li1+', 'Co3+')
# ('Li1+', 'Ni2+')
# ('Li1+', 'Cu2+')
# ('Li1+', 'Zn2+')
# ('Li1+', 'Ga3+')
# ('Li1+', 'Rb1+')
# ('Li1+', 'Sr2+')
# ('Li1+', 'Y3+')
# ('Li1+', 'Zr4+')
# ('Li1+', 'Nb5+')
# ('Li1+', 'Mo4+')
# ('Li1+', 'Tc4+')
# ('Li1+', 'Ru3+')
# ('Li1+', 'Rh3+')
# ('Li1+', 'Pd4+')
# ('Li1+', 'Ag1+')
# ('Li1+', 'Cd2+')
# ('Li1+', 'In3+')
# ('Li1+', 'Sn2+')
# ('Li1+', 'Sb3+')
# ('Li1+', 'Te2+')
# ('Li1+', 'Cs1+')
# ('Li1+', 'Ba2+')
# ('Li1+', 'La3+')
# ('Li1+', 'Ce3+')
# ('Li1+', 'Pr3+')
# ('Li1+', 'Nd3+')
# ('Li1+', 'Pm3+')
# ('Li1+', 'Sm3+')
# ('Li1+', 'Eu3+')
# ('Li1+', 'Gd3+')
# ('Li1+', 'Tb3+')
# ('Li1+', 'Dy3+')
# ('Li1+', 'Ho3+')
# ('Li1+', 'Er3+')
# ('Li1+', 'Tm3+')
# ('Li1+', 'Yb3+')
# ('Li1+', 'Lu3+')
# ('Li1+', 'Hf4+')
# ('Li1+', 'Ta5+')
# ...

# %%
res_scores_df = pd.DataFrame(res_scores)
res_scores_df.sort_values('pred_temp', ascending=False)
#res_scores_df.sort_values('pred_temp', ascending=False).to_csv('res_alloys_03_02.csv', sep=',', header=True, index=False)
# Out:
#      material1 material2             pred_temp  \
# 1736      Ag1+      Pu4+  [25.059359849858357]
# 1734      Ag1+       U6+  [24.464507548786415]
# 1735      Ag1+      Np5+  [23.037212536815495]
# 4         Li1+       K1+  [21.799146772357386]
# 279       Mg2+      Fr1+  [21.697646571891944]
# 456       Ca2+      Cs1+   [21.51385316166715]
# 486       Ca2+      Fr1+  [21.507933726823705]
# 135       Be2+      Po2+  [21.446287458818034]
# 307       Al3+      Nb5+  [21.281003497712685]
# 318       Al3+      Te2+   [21.21383279694045]
# 209       Na1+      Ra2+  [21.128402122114306]
# 317       Al3+      Sb3+   [21.04630652884757]
# 553       Sc3+      Fr1+   [21.01442662868295]
# 136       Be2+      Fr1+  [20.952570931901896]
# 1915      Te2+      Ba2+  [20.944302956222245]
# 7         Li1+      Ti4+  [20.890478023189683]
# 418        K1+      Fr1+  [20.784376733577663]
# 89        Be2+      Ga3+  [20.729116747876304]
# 1224      Rb1+      Fr1+  [20.691253264138407]
# ...

# %%
res05 = pd.read_csv('res_alloys_05_05.csv', header=0, sep=',')
res05.query("material1 in ['Ti4+']")
# Out:
#      material1 material2      pred_temp    weights
# 2         Ti4+      Ag1+  [22.38664756]  [0.5 0.5]
# 29        Ti4+      Nd3+   [8.69287338]  [0.5 0.5]
# 30        Ti4+      Nb5+   [8.59458635]  [0.5 0.5]
# 147       Ti4+      Ta5+   [6.45280273]  [0.5 0.5]
# 157       Ti4+       V5+   [6.34421878]  [0.5 0.5]
# 168       Ti4+      In3+   [6.20948243]  [0.5 0.5]
# 202       Ti4+      Sm3+   [5.98342136]  [0.5 0.5]
# 230       Ti4+      Pm3+   [5.84737555]  [0.5 0.5]
# 263       Ti4+      Tc4+   [5.64928196]  [0.5 0.5]
# 380       Ti4+      Gd3+   [5.08450337]  [0.5 0.5]
# 608       Ti4+      Th4+   [4.47355697]  [0.5 0.5]
# 632       Ti4+      Mo6+   [4.42919857]  [0.5 0.5]
# 634       Ti4+      Pb4+   [4.42732978]  [0.5 0.5]
# 694       Ti4+      Hf4+   [4.33287396]  [0.5 0.5]
# 706       Ti4+      Rb1+   [4.31797555]  [0.5 0.5]
# 719       Ti4+      Tb3+   [4.29465189]  [0.5 0.5]
# 787       Ti4+      Tl3+   [4.21925937]  [0.5 0.5]
# ...

# %%
res_scores_df = pd.DataFrame(res_scores)
res_scores_df.sort_values('pred_temp', ascending=False)
res_scores_df.sort_values('pred_temp', ascending=False).to_csv('res_alloys_025_05_025.csv', sep=',', header=True, index=False)

# %%
#test

n = 4
res_scores = []
for (_, row1), (_, row2), (_, row3) in tqdm(combinations(one_chast_plus.iterrows(), 3)):
    for _, row4 in test_minus.iterrows():
        
        p = np.ones(n)
        p[3] = (2*row1['mean_Valence']+1*row2['mean_Valence']+1*row3['mean_Valence'])/(2*row1['mean_Valence']+1*row2['mean_Valence']+1*row3['mean_Valence']+4*row4['mean_Valence']) 
        p[0] = 2*(1 - p[3])/4.
        p[1] = 1*(1 - p[3])/4.
        p[2] = 1*(1 - p[3])/4.
        #p[0] = 1/5.
        #p[1] = 0.
        #p[2] = 1/5.
        #p[3] = 3/5.
        #p[4] = 0.526
        ts = []
        for target_col in target_cols:
            t = [row1[target_col], row2[target_col], row3[target_col], row4[target_col]]
            ts.append(t)
    
        params = material(p,ts[0],ts[1],ts[2],ts[3],ts[4],ts[5],ts[6],ts[7],n)
        pred_temp = rfst.predict(params)
        res_scores.append({'material1':row1['material'], 'material2':row2['material'],'material3':row3['material'], 'material4':row4['material'], 'weights':p,'pred_temp':pred_temp})
# Out:
# 0it [00:00, ?it/s]C:\Users\SCIENTIST\Anaconda2\lib\site-packages\scipy\stats\stats.py:313: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(a)
# 374660it [10:52:15,  9.57it/s]

# %%
res_scores_df = pd.DataFrame(res_scores)
res_scores_df.sort_values('pred_temp', ascending=False)
res_scores_df.sort_values('pred_temp', ascending=False).to_csv('rfst_2114.csv', sep=',', header=True, index=False)
